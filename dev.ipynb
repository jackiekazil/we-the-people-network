# %%
import matplotlib.pyplot as plt

from dev import get_petitions
from network import create_edgelist, visualize_graph

petitions = get_petitions('GFxfKKgtbWWXnKB')
#p_issues = [(u'51212558a9a0b1143e00000d', u'4'), (u'51212558a9a0b1143e00000d', u'28')....]
p_issues = [(p.id,i['id']) for p in petitions for i in p.issues]

# %%
G = create_edgelist(p_issues)
visualize_graph(G, 125)
# Out:
# [2, 4, 6, 7, 7, 7, 8, 8, 8, 9, 17, 18, 21, 21, 21, 23, 23, 25, 25, 25, 25, 26, 26, 27, 27, 27, 28, 28, 29, 30, 30, 31, 31, 31, 31, 33, 34, 34, 34, 35, 35, 36, 36, 36, 36, 36, 36, 37, 37, 38, 38, 39, 39, 39, 39, 39, 40, 40, 40, 40, 40, 40, 40, 40, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 44, 44, 45, 46, 46, 46, 46, 46, 47, 47, 48, 48, 48, 48, 48, 48, 48, 49, 49, 50, 52, 52, 52, 52, 53, 54, 54, 54, 56, 56, 57, 57, 57, 57, 57, 57, 57, 57, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 60, 60, 61, 61, 62, 63, 63, 63, 63, 63, 64, 64, 64, 65, 65, 65, 65, 65, 65, 66, 66, 66, 68, 68, 68, 68, 69, 70, 70, 70, 71, 71, 72, 72, 73, 74, 74, 74, 74, 75, 75, 75, 76, 78, 78, 79, 80, 82, 82, 83, 85, 85, 85, 86, 88, 89, 89, 89, 89, 91, 92, 93, 94, 94, 95, 96, 97, 97, 98, 103, 103, 104, 104, 104, 104, 106, 107, 110, 110, 112, 113, 113, 113, 115, 115, 115, 115, 122, 123, 123, 123, 124, 127, 128, 130, 130, 131, 131, 131, 132, 132, 132, 132, 132, 132, 133, 133, 134, 135, 136, 137, 137, 138, 138, 138, 1
# ...
